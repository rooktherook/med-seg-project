# %%
import cv2
import os
import numpy as np


def inject_gaussian(image, mean = 0, sigma = 150):
    normalised_image = image.astype(np.float32) / 255.0 
    gaussian = np.random.normal(mean, sigma / 255.0, normalised_image.shape)
    noise = normalised_image + gaussian
    alt_image = np.clip(noise * 255, 0, 255).astype(np.uint8)
    return alt_image

def inject_poisson(image):
    scaled_image = image.astype(np.float32) / 255.0 * 100.0 
    noise = np.random.poisson(scaled_image) / 100

    alt_image = np.clip(noise * 255, 0, 255).astype(np.uint8) 
    return alt_image

def inject_gaussian_noise(input_folder, output_folder):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    for filename in os.listdir(input_folder):
        if filename.endswith(('.png', '.jpg', '.jpeg', '.bmp', '.tiff')):
            img_path = os.path.join(input_folder, filename)
            image = cv2.imread(img_path)

            noisy_image = inject_gaussian(image)
            
            output_path = os.path.join(output_folder, filename)
            cv2.imwrite(output_path, noisy_image)

            print(f"Processed and saved: {output_path}")

def inject_poisson_noise(input_folder, output_folder):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    for filename in os.listdir(input_folder):
        if filename.endswith(('.png', '.jpg', '.jpeg', '.bmp', '.tiff')):
            img_path = os.path.join(input_folder, filename)
            image = cv2.imread(img_path)

            noisy_image = inject_poisson(image)

            output_path = os.path.join(output_folder, filename)
            cv2.imwrite(output_path, noisy_image)

            print(f"Processed and saved: {output_path}")

def inject_both(input_folder, output_folder):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    for filename in os.listdir(input_folder):
        if filename.endswith(('.png', '.jpg', '.jpeg', '.bmp', '.tiff')):
            img_path = os.path.join(input_folder, filename)
            image = cv2.imread(img_path)

            poisson_image = inject_poisson(image)
            noisy_image = inject_gaussian(poisson_image, sigma = 100)

            output_path = os.path.join(output_folder, filename)
            cv2.imwrite(output_path, noisy_image)

            print(f"Processed and saved: {output_path}")

input_folder = 'doubleblur/images/val'
input_folder2 = 'doubleblur/images/train'
output_folder = 'doubleblur_noise/images/val'
output_folder2 = 'doubleblur_noise/images/train'

# gaussian_folder = 'Kvasir-SEG-NoiseG/images/train'
# poisson_folder = 'Kvasir-SEG-NoiseP/images/train'

# inject_gaussian_noise(input_folder, gaussian_folder)
# inject_poisson_noise(input_folder, poisson_folder)
inject_both(input_folder, output_folder)
inject_both(input_folder2, output_folder2)
# Out:
# Processed and saved: doubleblur_noise/images/val\test_img_0000_000.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_001.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_002.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_003.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_004.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_005.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_006.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_007.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_008.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_009.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_010.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_011.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_012.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_013.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_014.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_015.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_016.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_017.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_018.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_019.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_020.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_021.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_022.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_023.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_024.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_025.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_026.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_027.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_028.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_029.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_030.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_031.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_032.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_033.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_034.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_035.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_036.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_037.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_038.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_039.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_040.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_041.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_042.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_043.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_044.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_045.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_046.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_047.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_048.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_049.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_050.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_051.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_052.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_053.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_054.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_055.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_056.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_057.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_058.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_059.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_060.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_061.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_062.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_063.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_064.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_065.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_066.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_067.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_068.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_069.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_070.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_071.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_072.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_073.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_074.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_075.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_076.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_077.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_078.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_079.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_080.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_081.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_082.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_083.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_084.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_085.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_086.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_087.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_088.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_089.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_090.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_091.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_092.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_093.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_094.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_095.png
# Processed and saved: doubleblur_noise/images/val\test_img_0000_096.png
# Processed and saved: doubleblur_noise/images/val\test_img_0001_000.png
# Processed and saved: doubleblur_noise/images/val\test_img_0001_001.png
# Processed and saved: doubleblur_noise/images/val\test_img_0001_002.png
# Processed and saved: doubleblur_noise/images/val\test_img_0001_003.png
# Processed and saved: doubleblur_noise/images/val\test_img_0001_004.png
# Processed and saved: doubleblur_noise/images/val\test_img_0001_005.png
# Processed and saved: doubleblur_noise/images/val\test_img_0001_006.png
# Processed and saved: doubleblur_noise/images/val\test_img_0001_007.png
# Processed and saved: doubleblur_noise/images/val\test_img_0001_008.png
# Processed and saved: doubleblur_noise/images/val\test_img_0001_009.png
# Processed and saved: doubleblur_noise/images/val\test_img_0001_010.png
# Processed and saved: doubleblur_noise/images/val\test_img_0001_011.png
# Processed and saved: doubleblur_noise/images/val\test_img_0001_012.png
# Processed and saved: doubleblur_noise/images/val\test_img_0001_013.png
# Processed and saved: doubleblur_noise/images/val\test_img_0001_014.png
# Processed and saved: doubleblur_noise/images/val\test_img_0001_015.png
# Processed and saved: doubleblur_noise/images/val\test_img_0001_016.png
# Processed and saved: doubleblur_noise/images/val\test_img_0001_017.png
# Processed and saved: doubleblur_noise/images/val\test_img_0001_018.png
# Processed and saved: doubleblur_noise/images/val\test_img_0001_019.png
# Processed and saved: doubleblur_noise/images/val\test_img_0001_020.png
# Processed and saved: doubleblur_noise/images/val\test_img_0001_021.png
# Processed and saved: doubleblur_noise/images/val\test_img_0001_022.png
# Processed and saved: doubleblur_noise/images/val\test_img_0001_023.png
# Processed and saved: doubleblur_noise/images/val\test_img_0001_024.png
# Processed and saved: doubleblur_noise/images/val\test_img_0001_025.png
# Processed and saved: doubleblur_noise/images/val\test_img_0001_026.png
# Processed and saved: doubleblur_noise/images/val\test_img_0001_027.png
# Processed and saved: doubleblur_noise/images/val\test_img_0001_028.png
# Processed and saved: doubleblur_noise/images/val\test_img_0001_029.png
# Processed and saved: doubleblur_noise/images/val\test_img_0001_030.png
# Processed and saved: doubleblur_noise/images/val\test_img_0001_031.png
# Processed and saved: doubleblur_noise/images/val\test_img_0001_032.png
# Processed and saved: doubleblur_noise/images/val\test_img_0001_033.png
# Processed and saved: doubleblur_noise/images/val\test_img_0001_034.png
# Processed and saved: doubleblur_noise/images/val\test_img_0001_035.png
# Processed and saved: doubleblur_noise/images/val\test_img_0001_036.png
# Processed and saved: doubleblur_noise/images/val\test_img_0001_037.png
# Processed and saved: doubleblur_noise/images/val\test_img_0001_038.png
# Processed and saved: doubleblur_noise/images/val\test_img_0001
png
# Processed and saved: doubleblur_noise/images/train\train_img_0018_011.png
# Processed and saved: doubleblur_noise/images/train\train_img_0018_012.png
# Processed and saved: doubleblur_noise/images/train\train_img_0018_013.png
# Processed and saved: doubleblur_noise/images/train\train_img_0018_014.png
# Processed and saved: doubleblur_noise/images/train\train_img_0018_015.png
# Processed and saved: doubleblur_noise/images/train\train_img_0018_016.png
# Processed and saved: doubleblur_noise/images/train\train_img_0018_017.png
# Processed and saved: doubleblur_noise/images/train\train_img_0018_018.png
# Processed and saved: doubleblur_noise/images/train\train_img_0018_019.png
# Processed and saved: doubleblur_noise/images/train\train_img_0018_020.png
# Processed and saved: doubleblur_noise/images/train\train_img_0018_021.png
# Processed and saved: doubleblur_noise/images/train\train_img_0018_022.png
# Processed and saved: doubleblur_noise/images/train\train_img_0018_023.png
# Processed and saved: doubleblur_noise/images/train\train_img_0018_024.png
# Processed and saved: doubleblur_noise/images/train\train_img_0018_025.png
# Processed and saved: doubleblur_noise/images/train\train_img_0018_026.png
# Processed and saved: doubleblur_noise/images/train\train_img_0018_027.png
# Processed and saved: doubleblur_noise/images/train\train_img_0018_028.png
# Processed and saved: doubleblur_noise/images/train\train_img_0018_029.png
# Processed and saved: doubleblur_noise/images/train\train_img_0018_030.png
# Processed and saved: doubleblur_noise/images/train\train_img_0018_031.png
# Processed and saved: doubleblur_noise/images/train\train_img_0018_032.png
# Processed and saved: doubleblur_noise/images/train\train_img_0018_033.png
# Processed and saved: doubleblur_noise/images/train\train_img_0018_034.png
# Processed and saved: doubleblur_noise/images/train\train_img_0018_035.png
# Processed and saved: doubleblur_noise/images/train\train_img_0018_036.png
# Processed and saved: doubleblur_noise/images/train\train_img_0018_037.png
# Processed and saved: doubleblur_noise/images/train\train_img_0018_038.png
# Processed and saved: doubleblur_noise/images/train\train_img_0018_039.png
# Processed and saved: doubleblur_noise/images/train\train_img_0018_040.png
# Processed and saved: doubleblur_noise/images/train\train_img_0018_041.png
# Processed and saved: doubleblur_noise/images/train\train_img_0018_042.png
# Processed and saved: doubleblur_noise/images/train\train_img_0018_043.png
# Processed and saved: doubleblur_noise/images/train\train_img_0018_044.png
# Processed and saved: doubleblur_noise/images/train\train_img_0018_045.png
# Processed and saved: doubleblur_noise/images/train\train_img_0018_046.png
# Processed and saved: doubleblur_noise/images/train\train_img_0018_047.png
# Processed and saved: doubleblur_noise/images/train\train_img_0018_048.png
# Processed and saved: doubleblur_noise/images/train\train_img_0018_049.png
# Processed and saved: doubleblur_noise/images/train\train_img_0018_050.png
# Processed and saved: doubleblur_noise/images/train\train_img_0018_051.png
# Processed and saved: doubleblur_noise/images/train\train_img_0018_052.png
# Processed and saved: doubleblur_noise/images/train\train_img_0018_053.png
# Processed and saved: doubleblur_noise/images/train\train_img_0018_054.png
# Processed and saved: doubleblur_noise/images/train\train_img_0018_055.png
# Processed and saved: doubleblur_noise/images/train\train_img_0018_056.png
# Processed and saved: doubleblur_noise/images/train\train_img_0018_057.png
# Processed and saved: doubleblur_noise/images/train\train_img_0018_058.png
# Processed and saved: doubleblur_noise/images/train\train_img_0018_059.png
# Processed and saved: doubleblur_noise/images/train\train_img_0018_060.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_000.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_001.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_002.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_003.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_004.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_005.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_006.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_007.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_008.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_009.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_010.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_011.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_012.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_013.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_014.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_015.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_016.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_017.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_018.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_019.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_020.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_021.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_022.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_023.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_024.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_025.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_026.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_027.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_028.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_029.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_030.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_031.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_032.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_033.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_034.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_035.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_036.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_037.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_038.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_039.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_040.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_041.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_042.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_043.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_044.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_045.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_046.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_047.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_048.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_049.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_050.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_051.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_052.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_053.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_054.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_055.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_056.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_057.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_058.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_059.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_060.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_061.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_062.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_063.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_064.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_065.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_066.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_067.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_068.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_069.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_070.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_071.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_072.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_073.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_074.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_075.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_076.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_077.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_078.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_079.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_080.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_081.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_082.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_083.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_084.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_085.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_086.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_087.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_088.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_089.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_090.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_091.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_092.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_093.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_094.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_095.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_096.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_097.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_098.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_099.png
# Processed and saved: doubleblur_noise/images/train\train_img_0019_100.png

# %%
import cv2
import os
import numpy as np

def apply_motion_blur(image, kernel_size=15):
    kernel = np.zeros((kernel_size, kernel_size))
    kernel[int((kernel_size - 1)/2), :] = np.ones(kernel_size)
    kernel = kernel / kernel_size

    blurred = cv2.filter2D(image, -1, kernel)
    return blurred

def process_images(input_folder, output_folder, kernel_size=15):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    for filename in os.listdir(input_folder):
        if filename.endswith(('.png', '.jpg', '.jpeg', '.bmp', '.tiff')):
            img_path = os.path.join(input_folder, filename)
            image = cv2.imread(img_path)

            blurred_image = apply_motion_blur(image, kernel_size)
            blurred_image = apply_motion_blur(blurred_image, kernel_size)
            blurred_image = apply_motion_blur(blurred_image, kernel_size)
            blurred_image = apply_motion_blur(blurred_image, kernel_size)
            blurred_image = apply_motion_blur(blurred_image, kernel_size)
            blurred_image = apply_motion_blur(blurred_image, kernel_size)
            blurred_image = apply_motion_blur(blurred_image, kernel_size)
            blurred_image = apply_motion_blur(blurred_image, kernel_size)
            blurred_image = apply_motion_blur(blurred_image, kernel_size)
            blurred_image = apply_motion_blur(blurred_image, kernel_size)
            blurred_image = apply_motion_blur(blurred_image, kernel_size)
            blurred_image = apply_motion_blur(blurred_image, kernel_size)
            blurred_image = apply_motion_blur(blurred_image, kernel_size)
            blurred_image = apply_motion_blur(blurred_image, kernel_size)
            blurred_image = apply_motion_blur(blurred_image, kernel_size)
            blurred_image = apply_motion_blur(blurred_image, kernel_size)
            blurred_image = apply_motion_blur(blurred_image, kernel_size)
            blurred_image = apply_motion_blur(blurred_image, kernel_size)
            blurred_image = apply_motion_blur(blurred_image, kernel_size)
            blurred_image = apply_motion_blur(blurred_image, kernel_size)
            blurred_image = apply_motion_blur(blurred_image, kernel_size)
            blurred_image = apply_motion_blur(blurred_image, kernel_size)
            blurred_image = apply_motion_blur(blurred_image, kernel_size)
            blurred_image = apply_motion_blur(blurred_image, kernel_size)
            blurred_image = apply_motion_blur(blurred_image, kernel_size)
            blurred_image = apply_motion_blur(blurred_image, kernel_size)
            blurred_image = apply_motion_blur(blurred_image, kernel_size)
            blurred_image = apply_motion_blur(blurred_image, kernel_size)

            output_path = os.path.join(output_folder, filename)
            cv2.imwrite(output_path, blurred_image)

            print(f"Processed and saved: {output_path}")

input_folder = 'normal/images/train'
output_folder = 'blurred30x/images/train'
input_folder2 = 'normal/images/val'
output_folder2 = 'blurred30x/images/val'

# process_images(input_folder, output_folder, kernel_size=15)
process_images(input_folder2, output_folder2, kernel_size=15)
# Out:
# Processed and saved: blurred30x/images/val\test_img_0000_000.png
# Processed and saved: blurred30x/images/val\test_img_0000_001.png
# Processed and saved: blurred30x/images/val\test_img_0000_002.png
# Processed and saved: blurred30x/images/val\test_img_0000_003.png
# Processed and saved: blurred30x/images/val\test_img_0000_004.png
# Processed and saved: blurred30x/images/val\test_img_0000_005.png
# Processed and saved: blurred30x/images/val\test_img_0000_006.png
# Processed and saved: blurred30x/images/val\test_img_0000_007.png
# Processed and saved: blurred30x/images/val\test_img_0000_008.png
# Processed and saved: blurred30x/images/val\test_img_0000_009.png
# Processed and saved: blurred30x/images/val\test_img_0000_010.png
# Processed and saved: blurred30x/images/val\test_img_0000_011.png
# Processed and saved: blurred30x/images/val\test_img_0000_012.png
# Processed and saved: blurred30x/images/val\test_img_0000_013.png
# Processed and saved: blurred30x/images/val\test_img_0000_014.png
# Processed and saved: blurred30x/images/val\test_img_0000_015.png
# Processed and saved: blurred30x/images/val\test_img_0000_016.png
# Processed and saved: blurred30x/images/val\test_img_0000_017.png
# Processed and saved: blurred30x/images/val\test_img_0000_018.png
# Processed and saved: blurred30x/images/val\test_img_0000_019.png
# Processed and saved: blurred30x/images/val\test_img_0000_020.png
# Processed and saved: blurred30x/images/val\test_img_0000_021.png
# Processed and saved: blurred30x/images/val\test_img_0000_022.png
# Processed and saved: blurred30x/images/val\test_img_0000_023.png
# Processed and saved: blurred30x/images/val\test_img_0000_024.png
# Processed and saved: blurred30x/images/val\test_img_0000_025.png
# Processed and saved: blurred30x/images/val\test_img_0000_026.png
# Processed and saved: blurred30x/images/val\test_img_0000_027.png
# Processed and saved: blurred30x/images/val\test_img_0000_028.png
# Processed and saved: blurred30x/images/val\test_img_0000_029.png
# Processed and saved: blurred30x/images/val\test_img_0000_030.png
# Processed and saved: blurred30x/images/val\test_img_0000_031.png
# Processed and saved: blurred30x/images/val\test_img_0000_032.png
# Processed and saved: blurred30x/images/val\test_img_0000_033.png
# Processed and saved: blurred30x/images/val\test_img_0000_034.png
# Processed and saved: blurred30x/images/val\test_img_0000_035.png
# Processed and saved: blurred30x/images/val\test_img_0000_036.png
# Processed and saved: blurred30x/images/val\test_img_0000_037.png
# Processed and saved: blurred30x/images/val\test_img_0000_038.png
# Processed and saved: blurred30x/images/val\test_img_0000_039.png
# Processed and saved: blurred30x/images/val\test_img_0000_040.png
# Processed and saved: blurred30x/images/val\test_img_0000_041.png
# Processed and saved: blurred30x/images/val\test_img_0000_042.png
# Processed and saved: blurred30x/images/val\test_img_0000_043.png
# Processed and saved: blurred30x/images/val\test_img_0000_044.png
# Processed and saved: blurred30x/images/val\test_img_0000_045.png
# Processed and saved: blurred30x/images/val\test_img_0000_046.png
# Processed and saved: blurred30x/images/val\test_img_0000_047.png
# Processed and saved: blurred30x/images/val\test_img_0000_048.png
# Processed and saved: blurred30x/images/val\test_img_0000_049.png
# Processed and saved: blurred30x/images/val\test_img_0000_050.png
# Processed and saved: blurred30x/images/val\test_img_0000_051.png
# Processed and saved: blurred30x/images/val\test_img_0000_052.png
# Processed and saved: blurred30x/images/val\test_img_0000_053.png
# Processed and saved: blurred30x/images/val\test_img_0000_054.png
# Processed and saved: blurred30x/images/val\test_img_0000_055.png
# Processed and saved: blurred30x/images/val\test_img_0000_056.png
# Processed and saved: blurred30x/images/val\test_img_0000_057.png
# Processed and saved: blurred30x/images/val\test_img_0000_058.png
# Processed and saved: blurred30x/images/val\test_img_0000_059.png
# Processed and saved: blurred30x/images/val\test_img_0000_060.png
# Processed and saved: blurred30x/images/val\test_img_0000_061.png
# Processed and saved: blurred30x/images/val\test_img_0000_062.png
# Processed and saved: blurred30x/images/val\test_img_0000_063.png
# Processed and saved: blurred30x/images/val\test_img_0000_064.png
# Processed and saved: blurred30x/images/val\test_img_0000_065.png
# Processed and saved: blurred30x/images/val\test_img_0000_066.png
# Processed and saved: blurred30x/images/val\test_img_0000_067.png
# Processed and saved: blurred30x/images/val\test_img_0000_068.png
# Processed and saved: blurred30x/images/val\test_img_0000_069.png
# Processed and saved: blurred30x/images/val\test_img_0000_070.png
# Processed and saved: blurred30x/images/val\test_img_0000_071.png
# Processed and saved: blurred30x/images/val\test_img_0000_072.png
# Processed and saved: blurred30x/images/val\test_img_0000_073.png
# Processed and saved: blurred30x/images/val\test_img_0000_074.png
# Processed and saved: blurred30x/images/val\test_img_0000_075.png
# Processed and saved: blurred30x/images/val\test_img_0000_076.png
# Processed and saved: blurred30x/images/val\test_img_0000_077.png
# Processed and saved: blurred30x/images/val\test_img_0000_078.png
# Processed and saved: blurred30x/images/val\test_img_0000_079.png
# Processed and saved: blurred30x/images/val\test_img_0000_080.png
# Processed and saved: blurred30x/images/val\test_img_0000_081.png
# Processed and saved: blurred30x/images/val\test_img_0000_082.png
# Processed and saved: blurred30x/images/val\test_img_0000_083.png
# Processed and saved: blurred30x/images/val\test_img_0000_084.png
# Processed and saved: blurred30x/images/val\test_img_0000_085.png
# Processed and saved: blurred30x/images/val\test_img_0000_086.png
# Processed and saved: blurred30x/images/val\test_img_0000_087.png
# Processed and saved: blurred30x/images/val\test_img_0000_088.png
# Processed and saved: blurred30x/images/val\test_img_0000_089.png
# Processed and saved: blurred30x/images/val\test_img_0000_090.png
# Processed and saved: blurred30x/images/val\test_img_0000_091.png
# Processed and saved: blurred30x/images/val\test_img_0000_092.png
# Processed and saved: blurred30x/images/val\test_img_0000_093.png
# Processed and saved: blurred30x/images/val\test_img_0000_094.png
# Processed and saved: blurred30x/images/val\test_img_0000_095.png
# Processed and saved: blurred30x/images/val\test_img_0000_096.png
# Processed and saved: blurred30x/images/val\test_img_0001_000.png
# Processed and saved: blurred30x/images/val\test_img_0001_001.png
# Processed and saved: blurred30x/images/val\test_img_0001_002.png
# Processed and saved: blurred30x/images/val\test_img_0001_003.png
# Processed and saved: blurred30x/images/val\test_img_0001_004.png
# Processed and saved: blurred30x/images/val\test_img_0001_005.png
# Processed and saved: blurred30x/images/val\test_img_0001_006.png
# Processed and saved: blurred30x/images/val\test_img_0001_007.png
# Processed and saved: blurred30x/images/val\test_img_0001_008.png
# Processed and saved: blurred30x/images/val\test_img_0001_009.png
# Processed and saved: blurred30x/images/val\test_img_0001_010.png
# Processed and saved: blurred30x/images/val\test_img_0001_011.png
# Processed and saved: blurred30x/images/val\test_img_0001_012.png
# Processed and saved: blurred30x/images/val\test_img_0001_013.png
# Processed and saved: blurred30x/images/val\test_img_0001_014.png
# Processed and saved: blurred30x/images/val\test_img_0001_015.png
# Processed and saved: blurred30x/images/val\test_img_0001_016.png
# Processed and saved: blurred30x/images/val\test_img_0001_017.png
# Processed and saved: blurred30x/images/val\test_img_0001_018.png
# Processed and saved: blurred30x/images/val\test_img_0001_019.png
# Processed and saved: blurred30x/images/val\test_img_0001_020.png
# Processed and saved: blurred30x/images/val\test_img_0001_021.png
# Processed and saved: blurred30x/images/val\test_img_0001_022.png
# Processed and saved: blurred30x/images/val\test_img_0001_023.png
# Processed and saved: blurred30x/images/val\test_img_0001_024.png
# Processed and saved: blurred30x/images/val\test_img_0001_025.png
# Processed and saved: blurred30x/images/val\test_img_0001_026.png
# Processed and saved: blurred30x/images/val\test_img_0001_027.png
# Processed and saved: blurred30x/images/val\test_img_0001_028.png
# Processed and saved: blurred30x/images/val\test_img_0001_029.png
# Processed and saved: blurred30x/images/val\test_img_0001_030.png
# Processed and saved: blurred30x/images/val\test_img_0001_031.png
# Processed and saved: blurred30x/images/val\test_img_0001_032.png
# Processed and saved: blurred30x/images/val\test_img_0001_033.png
# Processed and saved: blurred30x/images/val\test_img_0001_034.png
# Processed and saved: blurred30x/images/val\test_img_0001_035.png
# Processed and saved: blurred30x/images/val\test_img_0001_036.png
# Processed and saved: blurred30x/images/val\test_img_0001_037.png
# Processed and saved: blurred30x/images/val\test_img_0001_038.png
# Processed and saved: blurred30x/images/val\test_img_0001_039.png
# Processed and saved: blurred30x/images/val\test_img_0001_040.png
# Processed and saved: blurred30x/images/val\test_img_0002_000.png
# Processed and saved: blurred30x/images/val\test_img_0002_001.png
# Processed and saved: blurred30x/images/val\test_img_0002_002.png
# Processed and saved: blurred30x/images/val\test_img_0002_003.png
# Processed and saved: blurred30x/images/val\test_img_0002_004.png
# Processed and saved: blurred30x/images/val\test_img_0002_005.png
# Processed and saved: blurred30x/images/val\test_img_0002_006.png
# Processed and saved: blurred30x/images/val\test_img_0002_007.png
# Processed and saved: blurred30x/images/val\test_img_0002_008.png
# Processed and saved: blurred30x/images/val\test_img_0002_009.png
# Processed and saved: blurred30x/images/val\test_img_0002_010.png
# Processed and saved: blurred30x/images/val\test_img_0002_011.png
# Processed and saved: blurred30x/images/val\test_img_0002_012.png
# Processed and saved: blurred30x/images/val\test_img_0002_013.png
# Processed and saved: blurred30x/images/val\test_img_0002_014.png
# Processed and saved: blurred30x/images/val\test_img_0002_015.png
# Processed and saved: blurred30x/images/val\test_img_0002_016.png
# Processed and saved: blurred30x/images/val\test_img_0002_017.png
# Processed and saved: blurred30x/images/val\test_img_0002_018.png
# Processed and saved: blurred30x/images/val\test_img_0002_019.png
# Processed and saved: blurred30x/images/val\test_img_0002_020.png
# Processed and saved: blurred30x/images/val\test_img_0002_021.png
# Processed and saved: blurred30x/images/val\test_img_0002_022.png
# Processed and saved: blurred30x/images/val\test_img_0002_023.png
# Processed and saved: blurred30x/images/val\test_img_0002_024.png
# Processed and saved: blurred30x/images/val\test_img_0002_025.png
# Processed and saved: blurred30x/images/val\test_img_0002_026.png
# Processed and saved: blurred30x/images/val\test_img_0002_027.png
# Processed and saved: blurred30x/images/val\test_img_0002_028.png
# Processed and saved: blurred30x/images/val\test_img_0002_029.png
# Processed and saved: blurred30x/images/val\test_img_0002_030.png
# Processed and saved: blurred30x/images/val\test_img_0003_000.png
# Processed and saved: blurred30x/images/val\test_img_0003_001.png
# Processed and saved: blurred30x/images/val\test_img_0003_002.png
# Processed and saved: blurred30x/images/val\test_img_0003_003.png
# Processed and saved: blurred30x/images/val\test_img_0003_004.png
# Processed and saved: blurred30x/images/val\test_img_0003_005.png
# Processed and saved: blurred30x/images/val\test_img_0003_006.png
# Processed and saved: blurred30x/images/val\test_img_0003_007.png
# Processed and saved: blurred30x/images/val\test_img_0003_008.png
# Processed and saved: blurred30x/images/val\test_img_0003_009.png
# Processed and saved: blurred30x/images/val\test_img_0003_010.png
# Processed and saved: blurred30x/images/val\test_img_0003_011.png
# Processed and saved: blurred30x/images/val\test_img_0003_012.png
# Processed and saved: blurred30x/images/val\test_img_0003_013.png
# Processed and saved: blurred30x/images/val\test_img_0003_014.png
# Processed and saved: blurred30x/images/val\test_img_0003_015.png
# Processed and saved: blurred30x/images/val\test_img_0003_016.png
# Processed and saved: blurred30x/images/val\test_img_0003_017.png
# Processed and saved: blurred30x/images/val\test_img_0003_018.png
# Processed and saved: blurred30x/images/val\test_img_0003_019.png
# Processed and saved: blurred30x/images/val\test_img_0003_020.png
# Processed and saved: blurred30x/images/val\test_img_0003_021.png
# Processed and saved: blurred30x/images/val\test_img_0003_022.png
# Processed and saved: blurred30x/images/val\test_img_0003_023.png
# Processed and saved: blurred30x/images/val\test_img_0003_024.png
# Processed and saved: blurred30x/images/val\test_img_0003_025.png
# Processed and saved: blurred30x/images/val\test_img_0003_026.png
# Processed and saved: blurred30x/images/val\test_img_0003_027.png
# Processed and saved: blurred30x/images/val\test_img_0003_028.png
# Processed and saved: blurred30x/images/val\test_img_0003_029.png
# Processed and saved: blurred30x/images/val\test_img_0003_030.png
# Processed and saved: blurred30x/images/val\test_img_0003_031.png
# Processed and saved: blurred30x/images/val\test_img_0003_032.png
# Processed and saved: blurred30x/images/val\test_img_0003_033.png
# Processed and saved: blurred30x/images/val\test_img_0003_034.png
# Processed and saved: blurred30x/images/val\test_img_0003_035.png
# Processed and saved: blurred30x/images/val\test_img_0003_036.png
# Processed and saved: blurred30x/images/val\test_img_0003_037.png
# Processed and saved: blurred30x/images/val\test_img_0003_038.png
# Processed and saved: blurred30x/images/val\test_img_0003_039.png
# Processed and saved: blurred30x/images/val\test_img_0003_040.png
# Processed and saved: blurred30x/images/val\test_img_0003_041.png
# Processed and saved: blurred30x/images/val\test_img_0003_042.png
# Processed and saved: blurred30x/images/val\test_img_0003_043.png
# Processed and saved: blurred30x/images/val\test_img_0003_044.png
# Processed and saved: blurred30x/images/val\test_img_0003_045.png
# Processed and saved: blurred30x/images/val\test_img_0003_046.png
# Processed and saved: blurred30x/images/val\test_img_0003_047.png
# Processed and saved: blurred30x/images/val\test_img_0003_048.png
# Processed and saved: blurred30x/images/val\test_img_0003_049.png
# Processed and saved: blurred30x/images/val\test_img_0003_050.png
# Processed and saved: blurred30x/images/val\test_img_0003_051.png
# Processed and saved: blurred30x/images/val\test_img_0003_052.png
# Processed and saved: blurred30x/images/val\test_img_0003_053.png
# Processed and saved: blurred30x/images/val\test_img_0003_054.png
# Processed and saved: blurred30x/images/val\test_img_0003_055.png
# Processed and saved: blurred30x/images/val\test_img_0003_056.png
# Processed and saved: blurred30x/images/val\test_img_0003_057.png
# Processed and saved: blurred30x/images/val\test_img_0003_058.png
# Processed and saved: blurred30x/images/val\test_img_0003_059.png
# Processed and saved: blurred30x/images/val\test_img_0003_060.png
# Processed and saved: blurred30x/images/val\test_img_0003_061.png
# Processed and saved: blurred30x/images/val\test_img_0003_062.png
# Processed and saved: blurred30x/images/val\test_img_0003_063.png
# Processed and saved: blurred30x/images/val\test_img_0003_064.png
# Processed and saved: blurred30x/images/val\test_img_0003_065.png
# Processed and saved: blurred30x/images/val\test_img_0003_066.png
# Processed and saved: blurred30x/images/val\test_img_0003_067.png
# Processed and saved: blurred30x/images/val\test_img_0003_068.png
# Processed and saved: blurred30x/images/val\test_img_0003_069.png
# Processed and saved: blurred30x/images/val\test_img_0003_070.png
# Processed and saved: blurred30x/images/val\test_img_0003_071.png
# Processed and saved: blurred30x/images/val\test_img_0003_072.png
# Processed and saved: blurred30x/images/val\test_img_0003_073.png
# Processed and saved: blurred30x/images/val\test_img_0003_074.png
# Processed and saved: blurred30x/images/val\test_img_0003_075.png
# Processed and saved: blurred30x/images/val\test_img_0003_076.png
# Processed and saved: blurred30x/images/val\test_img_0003_077.png
# Processed and saved: blurred30x/images/val\test_img_0003_078.png
# Processed and saved: blurred30x/images/val\test_img_0003_079.png
# Processed and saved: blurred30x/images/val\test_img_0003_080.png
# Processed and saved: blurred30x/images/val\test_img_0003_081.png
# Processed and saved: blurred30x/images/val\test_img_0003_082.png
# Processed and saved: blurred30x/images/val\test_img_0003_083.png
# Processed and saved: blurred30x/images/val\test_img_0003_084.png
# Processed and saved: blurred30x/images/val\test_img_0003_085.png
# Processed and saved: blurred30x/images/val\test_img_0003_086.png
# Processed and saved: blurred30x/images/val\test_img_0003_087.png
# Processed and saved: blurred30x/images/val\test_img_0003_088.png
# Processed and saved: blurred30x/images/val\test_img_0003_089.png
# Processed and saved: blurred30x/images/val\test_img_0003_090.png
# Processed and saved: blurred30x/images/val\test_img_0003_091.png
# Processed and saved: blurred30x/images/val\test_img_0003_092.png
# Processed and saved: blurred30x/images/val\test_img_0004_000.png
# Processed and saved: blurred30x/images/val\test_img_0004_001.png
# Processed and saved: blurred30x/images/val\test_img_0004_002.png
# Processed and saved: blurred30x/images/val\test_img_0004_003.png
# Processed and saved: blurred30x/images/val\test_img_0004_004.png
# Processed and saved: blurred30x/images/val\test_img_0004_005.png
# Processed and saved: blurred30x/images/val\test_img_0004_006.png
# Processed and saved: blurred30x/images/val\test_img_0004_007.png
# Processed and saved: blurred30x/images/val\test_img_0004_008.png
# Processed and saved: blurred30x/images/val\test_img_0004_009.png
# Processed and saved: blurred30x/images/val\test_img_0004_010.png
# Processed and saved: blurred30x/images/val\test_img_0004_011.png
# Processed and saved: blurred30x/images/val\test_img_0004_012.png
# Processed and saved: blurred30x/images/val\test_img_0004_013.png
# Processed and saved: blurred30x/images/val\test_img_0004_014.png
# Processed and saved: blurred30x/images/val\test_img_0004_015.png
# Processed and saved: blurred30x/images/val\test_img_0004_016.png
# Processed and saved: blurred30x/images/val\test_img_0004_017.png
# Processed and saved: blurred30x/images/val\test_img_0004_018.png
# Processed and saved: blurred30x/images/val\test_img_0004_019.png
# Processed and saved: blurred30x/images/val\test_img_0004_020.png
# Processed and saved: blurred30x/images/val\test_img_0004_021.png
# Processed and saved: blurred30x/images/val\test_img_0004_022.png
# Processed and saved: blurred30x/images/val\test_img_0004_023.png
# Processed and saved: blurred30x/images/val\test_img_0004_024.png
# Processed and saved: blurred30x/images/val\test_img_0004_025.png
# Processed and saved: blurred30x/images/val\test_img_0004_026.png
# Processed and saved: blurred30x/images/val\test_img_0004_027.png
# Processed and saved: blurred30x/images/val\test_img_0004_028.png
# Processed and saved: blurred30x/images/val\test_img_0004_029.png
# Processed and saved: blurred30x/images/val\test_img_0004_030.png
# Processed and saved: blurred30x/images/val\test_img_0004_031.png
# Processed and saved: blurred30x/images/val\test_img_0004_032.png
# Processed and saved: blurred30x/images/val\test_img_0004_033.png
# Processed and saved: blurred30x/images/val\test_img_0004_034.png
# Processed and saved: blurred30x/images/val\test_img_0004_035.png
# Processed and saved: blurred30x/images/val\test_img_0004_036.png
# Processed and saved: blurred30x/images/val\test_img_0004_037.png
# Processed and saved: blurred30x/images/val\test_img_0004_038.png
# Processed and saved: blurred30x/images/val\test_img_0004_039.png
# Processed and saved: blurred30x/images/val\test_img_0004_040.png
# Processed and saved: blurred30x/images/val\test_img_0004_041.png
# Processed and saved: blurred30x/images/val\test_img_0004_042.png
# Processed and saved: blurred30x/images/val\test_img_0004_043.png
# Processed and saved: blurred30x/images/val\test_img_0004_044.png
# Processed and saved: blurred30x/images/val\test_img_0004_045.png
# Processed and saved: blurred30x/images/val\test_img_0004_046.png
# Processed and saved: blurred30x/images/val\test_img_0004_047.png
# Processed and saved: blurred30x/images/val\test_img_0004_048.png
# Processed and saved: blurred30x/images/val\test_img_0004_049.png
# Processed and saved: blurred30x/images/val\test_img_0004_050.png
# Processed and saved: blurred30x/images/val\test_img_0004_051.png
# Processed and saved: blurred30x/images/val\test_img_0004_052.png
# Processed and saved: blurred30x/images/val\test_img_0004_053.png
# Processed and saved: blurred30x/images/val\test_img_0004_054.png
# Processed and saved: blurred30x/images/val\test_img_0004_055.png
# Processed and saved: blurred30x/images/val\test_img_0004_056.png
# Processed and saved: blurred30x/images/val\test_img_0004_057.png
# Processed and saved: blurred30x/images/val\test_img_0004_058.png
# Processed and saved: blurred30x/images/val\test_img_0004_059.png
# Processed and saved: blurred30x/images/val\test_img_0004_060.png
# Processed and saved: blurred30x/images/val\test_img_0004_061.png
# Processed and saved: blurred30x/images/val\test_img_0004_062.png
# Processed and saved: blurred30x/images/val\test_img_0004_063.png
# Processed and saved: blurred30x/images/val\test_img_0004_064.png
